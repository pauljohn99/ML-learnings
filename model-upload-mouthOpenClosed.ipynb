# %% [markdown]
# <a href="https://colab.research.google.com/github/pauljohn99/ML-learnings/blob/main/model-upload-mouthOpenClosed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub

# %%
model = tf.keras.models.load_model(
       ("/content/my_keras_model.h5"),
       custom_objects={'KerasLayer':hub.KerasLayer}
)

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
class_names=["closed","open"]

# %%
img=cv2.imread("/content/5-open.png")
print(img.shape)
img=cv2.resize(img,[384,384])
cv2_imshow(img)
print(img.shape)
# class_names = tuple(train_ds.class_names)
prediction_scores = model.predict(np.expand_dims(img, axis=0))
predicted_index = np.argmax(prediction_scores)
print(predicted_index)
print("Predicted label: " + class_names[predicted_index])
# Out:
# (1536, 2048, 3)
# <PIL.Image.Image image mode=RGB size=384x384 at 0x7F91AEC93940>
# (384, 384, 3)
# 1/1 [==============================] - 1s 528ms/step
# 0
# Predicted label: closed
