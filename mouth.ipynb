# %% [markdown]
# <a href="https://colab.research.google.com/github/pauljohn99/ML-learnings/blob/main/mouth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
image = cv2.imread("/content/open3.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=612x612 at 0x7F3393828CA0>

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_alt2.xml')
mouthCascade = cv2.CascadeClassifier("/content/haarcascade_mcs_mouth (1).xml")

# %%
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), 
                  (255, 0, 0), 2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = image[y:y+h, x:x+w]  
    cv2_imshow(roi_gray)
    mouth, rejectLevels, levelWeights = mouthCascade.detectMultiScale3(roi_gray,outputRejectLevels=True)
    print(max(levelWeights))
    print(levelWeights)
    # print(levelWeights.index(max(levelWeights)))
    newmax= np.where(levelWeights==max(levelWeights))[0]
    mou=mouth[newmax]
    width=mou[0][2]
    height=mou[0][3]
    area=width*height
    print(area)

print(area)
# Out:
# <PIL.Image.Image image mode=L size=318x318 at 0x7F33937AC9A0>
# 1.5071803315659054
# [0.97930224 0.89692624 1.50718033 0.64477927 1.23101099]
# 4860
# 4860
